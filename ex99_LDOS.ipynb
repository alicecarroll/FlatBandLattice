# %%
# Integrate normal state LDOS in energy window around half-filling, plot in real space
# Identify sites on which the flat bands have finite support (finite LDOS)
# Add on-site energy shift term only to those sites, plot resulting band structure for different shifts: can the flat bands be removed from the spectrum (non-singular band crossings)?
