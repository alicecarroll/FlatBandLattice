# %%
# Runtime: ~3 minutes

import numpy as np
import matplotlib.pyplot as plt

from importlib import reload
from tblib import models, plotting
reload(models)
reload(plotting)

# Define model size
N = 4

# Create model instances
dvals = [0.1, 0.5,]

# Define Figure
fig, axes = plt.subplots(len(dvals),6,figsize=(12,4*len(dvals)))

nk_dos = 2

for i, dval in enumerate(dvals):

    model = models.DSLmodel(N=N)
    delta_vec = dval * np.ones(model.nsites)
    model.delta = delta_vec

    axes[i, 0] = plotting.plot_bands(model, bdg=True, nk=500, hsp_path='GYMXGMH', ax=axes[i, 0]);
    axes[i, 1] = plotting.plot_DOS(model, bdg=True, nk=nk_dos, elim=axes[i, 0].get_ylim(), ax=axes[i, 1], ylabel=None);


    model = models.dDSLmodel(N=N)
    delta_vec = dval * np.ones(model.nsites)
    model.delta = delta_vec

    axes[i, 2] = plotting.plot_bands(model, bdg=True, nk=500, hsp_path='GYMXGMH', ax=axes[i, 2], ylabel=None);
    axes[i, 3] = plotting.plot_DOS(model, bdg=True, nk=nk_dos, elim=axes[i, 2].get_ylim(), ax=axes[i, 3], ylabel=None);

    model = models.LiebNmodel(N=N)
    model.delta = dval

    axes[i, 4] = plotting.plot_bands(model, bdg=True, nk=500, hsp_path='GYMXGMH', ax=axes[i, 4], ylabel=None);
    axes[i, 5] = plotting.plot_DOS(model, bdg=True, nk=nk_dos, elim=axes[i, 4].get_ylim(), ax=axes[i, 5], ylabel=None);
